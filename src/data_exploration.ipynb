# %%
import numpy as np
import matplotlib.pyplot as plt

from problem import get_train_data, get_test_data
from utils import cell_detection, brightness_correction

# %%
videos_train, label_train = get_train_data("../")
videos_test, label_test= get_test_data("../")

# %%
labs, counts = np.unique(label_train, return_counts=True)
plt.bar(labs, counts/max(counts))
plt.title("Barplot of class distribution in the train dataset")
plt.show()

# %%
labs, counts = np.unique(label_test, return_counts=True)
plt.bar(labs, counts/max(counts))
plt.title("Barplot of class distribution in the test dataset")
plt.show()

# %%
vid = videos_train[10]
print(vid.nb_frames)
print(vid.img_size)
print(vid.frame_times.shape)
# Out:
# 300
# [250, 250]
# (300,)

# %%
# Visualisation de l'histogramme des départs de vidéo
import matplotlib.pyplot as plt

start = []
for x in videos_test:
    start.append(min(x.frame_times))
labs, counts = np.unique(start, return_counts=True)
plt.bar(labs, counts)
plt.show()

# %%
# vid.read_frame(frame_time = 30)
# vid.read_sequence(begin_time=None, end_time=None) # toute la vidéo
# vid.read_samples(selected_times=None)
img = vid.read_frame(frame_time = 50)

plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show()

# %%
image = brightness_correction(img)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

# %%
image = cell_detection(image, display=True)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()
